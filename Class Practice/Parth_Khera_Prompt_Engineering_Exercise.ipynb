# %% [markdown]
# **Name: Parth Khera**
#
# **Class: CSE-A**
#
# **Roll No.: 169-CSE-A-23**
#
# **Enrollment No.: 35820802723**

# %% [markdown]
# # Prompt Engineering Exercise
# ### Zero-shot, Few-shot & Chain-of-Thought Prompting
#
# **Instructions:** Work through each section in order. Run the setup cell first. Fill in every cell marked `# TODO`, then answer the reflection questions in the markdown cells provided. Write your answers directly in this notebook.

# %% [markdown]
# ## Setup
#
# Run this cell once before starting. It installs and loads the model we'll use for all exercises.

# %%
# !pip install -q transformers

from transformers import pipeline
generator = pipeline('text-generation', model='gpt2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %% [markdown]
# ---
# ## Part 1 — Zero-shot Prompting
#
# **Concept:** In zero-shot prompting, you give the model an instruction with **no examples** and rely on its pre-trained knowledge to produce the answer.
#
# **Task 1.1:** Write a zero-shot prompt asking the model to classify the sentiment of the review below as Positive or Negative.
#
# > Review: "The service was slow and the staff were rude."

# %%
# TODO: write a zero-shot prompt for sentiment classification
prompt_zero = "The cricket match was very interesting due to performance of virat kohli in india vs pakistan match."

result = generator(prompt_zero, max_new_tokens=30, num_return_sequences=1)
print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The cricket match was very interesting due to performance of virat kohli in india vs pakistan match. We were all really happy with the results because we are used to seeing a lot of batsmen in the match. The team was much better than it

# %% [markdown]
# **Task 1.2:** Try a second zero-shot task of your own choice (e.g. translation, summarization, or classifying a different sentence). Write the prompt and run it.

# %%
# TODO: write your own zero-shot prompt for a task of your choice
prompt_zero_2 = "The Kargil War was "

result = generator(prompt_zero_2, max_new_tokens=100, num_return_sequences=1)
print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=100) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The Kargil War was  a major, and ultimately decisive, turning point for the world, and for humanity as a whole. It was a major turning point in the history of the world. It is a pivotal moment in the battle of Armageddon, and is also the central point for the history of the world today.
# The Kargil War:
# When the world was attacked and the armies of the world were sent to the brink of failure, the war began. In the face of the armies of the

# %% [markdown]
# **Reflection 1:** In your own words, when would you use zero-shot prompting instead of giving examples? Write 2–3 sentences below.
#
# *Your answer:*
#
# Zero-shot prompting is useful when the task is simple and the model already has enough knowledge to perform it without examples. It saves time because no sample inputs or outputs are needed, making it suitable for common tasks such as classification, translation, or summarization.

# %% [markdown]
# ---
# ## Part 2 — Few-shot Prompting
#
# **Concept:** In few-shot prompting, you give the model a few worked examples before your real question, so it can pick up the pattern (this is called **in-context learning** — no fine-tuning happens).
#
# **Task 2.1:** Below is an incomplete few-shot prompt turning adjectives into nouns. Complete the pattern by adding **two more** adjective/noun example pairs before the final unfinished one, then run it.

# %%
# TODO: add two more Adjective/Noun example pairs, keeping the same format
prompt_few = """
Adjective: happy, Noun: happiness
Adjective: lonely, Noun: loneliness
Adjective: heavy, Noun: heaviness
Adjective: lazy, Noun:"""

result = generator(prompt_few, max_new_tokens=5, num_return_sequences=1)
print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=5) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Adjective: happy, Noun: happiness
# Adjective: lonely, Noun: loneliness
# Adjective: heavy, Noun: heaviness
# Adjective: lazy, Noun: laziness
# Adject

# %% [markdown]
# **Task 2.2:** Design your own few-shot prompt for a *different* pattern (for example: country → capital, word → opposite, or singular → plural). Include at least 3 examples before the final unfinished one.

# %%
# TODO: write your own few-shot prompt with at least 3 examples
prompt_few_2 = """
Country: India, Capital: Delhi
Country: USA, Capital: Washington DC
Country: Japan, Capital: Tokyo
Country: Australia, Capital:"""

result = generator(prompt_few_2, max_new_tokens=3, num_return_sequences=1)
print(result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=3) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Country: India, Capital: Delhi
# Country: USA, Capital: Washington DC
# Country: Japan, Capital: Tokyo
# Country: Australia, Capital: Canberra
# Country

# %% [markdown]
# **Reflection 2:** Compare your zero-shot and few-shot results. Did giving examples change the quality or format of the output? Explain in 2–3 sentences.
#
# *Your answer:*
#
# The few-shot prompt produced output that followed the same format as the examples, making the response more consistent. Giving examples helped the model better understand the expected pattern and improved the accuracy compared to the zero-shot prompt.

# %% [markdown]
# ---
# ## Part 3 — Chain-of-Thought (CoT) Prompting
#
# **Concept:** CoT prompting asks the model to reason **step by step** instead of jumping straight to an answer. This is especially useful for math and logic problems.
#
# **Task 3.1:** Below is a word problem. First, run it with a **direct** prompt (no step-by-step instruction) and observe the answer.

# %%
question = "A store had 24 candies. It sold 9 and then received a new box of 15. How many candies does the store have now?"

# Direct (non-CoT) prompt
prompt_direct = f"Question: {question}\nAnswer:"

result_direct = generator(prompt_direct, max_new_tokens=40, num_return_sequences=1)
print(result_direct[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=40) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Question: A store had 24 candies. It sold 9 and then received a new box of 15. How many candies does the store have now?
# Answer: The store says it has 24 candies. It's not that many.
# The store was trying to find the correct number of candies as the number of candles was not the correct number. It

# %% [markdown]
# **Task 3.2:** Now rewrite the prompt to trigger Chain-of-Thought reasoning by adding a phrase like *"Let's think step by step."* Run it and compare the output to Task 3.1.

# %%
# TODO: build a Chain-of-Thought version of the prompt
prompt_cot = f"Question: {question}\nAnswer: Let's think step by step."

result_cot = generator(prompt_cot, max_new_tokens=60, num_return_sequences=1)
print(result_cot[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Question: A store had 24 candies. It sold 9 and then received a new box of 15. How many candies does the store have now?
# Answer: Let's think step by step. Look at these numbers. The stores are now full of 14 candies. It is very difficult to find the ones that were in a box.
# If you look at the number of bottles that were in the store, the number of candies was higher than the number of bottles that were shipped.

# %% [markdown]
# **Task 3.3:** Write your own multi-step word problem (addition, subtraction, or multiplication) and test it with both a direct prompt and a CoT prompt.

# %%
# TODO: your own word problem
my_question = "(10+4)*(4-1)+99*4"

# Direct prompt
prompt_my_direct = f"Question: {my_question}\nAnswer:"
result = generator(prompt_my_direct, max_new_tokens=30, num_return_sequences=1)
print("DIRECT:\n", result[0]['generated_text'])

# CoT prompt
prompt_my_cot = f"Question: {my_question}\nAnswer: Let's think step by step."
result = generator(prompt_my_cot, max_new_tokens=60, num_return_sequences=1)
print("\nCHAIN-OF-THOUGHT:\n", result[0]['generated_text'])
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [transformers] Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# DIRECT:
#  Question: (10+4)*(4-1)+99*4
# Answer: (9+4)*(4-2)+99*4
# Answer: (9+4)*(4-3)+99*4
#
#
# CHAIN-OF-THOUGHT:
#  Question: (10+4)*(4-1)+99*4
# Answer: Let's think step by step. The sum of four numbers on a line can be computed by multiplying the first four by the sum of the next three numbers. (The only difference is the number of digits.)
# I don't know whether that is a natural extension of the real-world math, or whether there is some code that

# %% [markdown]
# **Reflection 3:** Did the CoT prompt produce more accurate or more logically structured reasoning than the direct prompt? Note: GPT-2 is a small, older model, so CoT may not always fix its mistakes — describe what you actually observed.
#
# *Your answer:*
#
# The Chain-of-Thought prompt generally produced a more structured response by attempting to reason through the problem before giving the final answer. However, since GPT-2 is a relatively small and older language model, it may still make calculation or reasoning mistakes even when asked to think step by step.

# %% [markdown]
# ---
# ## Part 4 — Wrap-up Questions
#
# Answer briefly in your own words:
#
# 1. What is the key difference between zero-shot and few-shot prompting?
# 2. Why is few-shot prompting sometimes called "in-context learning" rather than training?
# 3. When is Chain-of-Thought prompting most useful, and why?
# 4. Based on your experiments, what is one limitation of GPT-2 you noticed when generating answers?
#
# *Your answers:*
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# 1.) Zero-shot prompting gives the model only an instruction without any examples, while few-shot prompting provides a few input-output examples to help the model understand the required pattern before solving the actual task.
#
# 2.) Few-shot prompting is called in-context learning because the model learns form the examples provided within the prompt during interference. The model's parameters are not updated, so no actual training or fine-tuning takea place.
#
# 3.) Chain-of-Thought prompting is most useful for complex tasks such as mathematical problems, logical reasoning, coding, and multi-step decision-making. It encourages the model to work though intermediate reasoning before producing the final answer, which can improve accuracy on difficult problems.
#
# 4.) GPT-2 sometimes generates incomplete, repititive, or incorrect responses, especially for reasoning and arithmetic tasks. It may also fail to follow instructions consistently because it is an older and smaller language model compared to modern instruction-tuned models.
